# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Комментарий ревьюера</b>
#
#
# Привет,  Владимир! Давай знакомиться! Меня зовут Дмитрий Махортов, и я буду проверять твой проект. Сразу предлагаю общение на «ты» 🙂, но если тебе это не комфортно, то дай знать, и мы перейдем на «вы».
#
# Моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе погрузиться в увлекательный мир работы с данными и вырасти в крепкого профи. Это отдаленная цель. А ближайшая - сделать твою работу еще лучше )).
#
#
# Все ключевые этапы в работе выполнены, и я вижу что с проектом ты справшяешься. Есть моменты, которые нужно доработать, но я уверен, у тебя все получится.
#
# Расскажу как обычно проходит проверка:
# Бывают моменты, которые требуют пристального внимания. Комментарии по ним выделены <span style='background-color:#F7B3A4'> красным цветом </span> и обозначены значком 🛑. После их доработки проект будет принят.  🙂
#
# <span style='background-color:#B7EBA7'> Зеленым цветом </span> и значком ✅ отмечены удачные и элегантные решения, на которые можно опираться в будущих проектах. Или советы «со звездочкой», которые помогут тебе в будущем.
#
# <span style='background-color:#F9EDA6'>Жёлтым цветом </span> и значком ⚠️ выделено то, что в следующий раз можно сделать по-другому. Ты можешь учесть эти комментарии при выполнении будущих заданий или доработать проект сейчас (однако это не обязательно).
#
# Давай работать над проектом в диалоге: **если ты что-то меняешь в проекте по моим рекомендациям — пиши об этом**. Выбери для своих комментариев какой-то заметный цвет, так мне будет легче отследить изменения. Пожалуйста, **не перемещай, не изменяй и не удаляй мои комментарии**. Всё это поможет выполнить повторную проверку твоего проекта оперативнее.
# </div>
#
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>образец комментария студента</b></font>
#
# Можешь использовать этот комментарий. Просто удали этот текст и вместо него напиши свой 🙂
#
# </div>

# %% [markdown]
# <div style="background-color:black; color:#ffffff; text-align:center; padding:2%">
#
# **Владимир:** Привет, дорогой мой ревьюер. У меня, к тебе, вопрос по проекту.
#
# У нас целевой признак содержит выбросы. Вопрос, какой наилучший способ для обработки данных выбросов и нужно ли это делать? Интересует именно, практические подходы из реальной практики DS, а не теоретические. То есть, те, которые проверены на практике DS специалистами.
#
# Я прочитал не одну статью, по-данному вопросу. В них, почти во всех, указывают на необходимость обязательной обработки выбросов в целевом признаке. Подход следующий. Сначала, применяем log transformation или другую трансформацию (преобразование) целевого признака, для приведения распределения его значений к нормальному или максимально близкое к нормальному. Если результат обучения модели не очень, просто удаляем выбросы.
#
# Есть альтернативное мнение, что лучше не обрабатывать целевой признак.
#
#
# Да, эти вопросы в контексте задачи регрессии (нашей задачи).
#
# p.s. Под обработкой целевого признака, в датасете, подразумевается обработка только в обучающей выборке.

# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Комментарий ревьюера</b>
#
# Да, вопрос ты задаешь непростой и насколько я понимаю вокруг удаления выбросов у тебя строится все усложнения в преокте.
#
# Могу сказать свое отношение к этому вопросу:
#
#  - выброс выбросу рознь и всегда нужно разбираться с природой, а не просто удалять по принципу "полтора интерквартильныхразмаха от Q1 или Q3. Потом что даже в нормальном распределении будут значения, принадлежащие этому распределению, но выходящие за усы. Поэтому боксплот лучше использовать как инфомрацию к размышлению, но обращаться к экспертам в области. Я не считаю выбросами людей старше 70 лет, потому что для человека это нормально,что кто-то доживает до 90-100 (хоть и редко). А вот возраст 200 лет или -10 лет - это повод поискать ошибки в данных (и в этом случае можно удалить аномалии из всех данных, включая тестовые)
#  - если удалять выбросы - то конечно жетолько из обучающих данных
#  - удалять ли выбросы из обучающих данных - вопрос открытый. Согласен, что есть разные точки зрения. В любом случае советую начинать с простого рабочего бейзлайна - попробовать не удалять.  Ну а если после этого все-таки стоит задача улучшить метрику, то да, возможно стоит провести эксперименты с чисткой.
#  - преобразованием выборки чтобы оно начало повторять нормальное распределение мне заниматься не доводилось
#
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color: rgb(10, 255, 10);;color:#8737bf">
#     <font size="3"><b>Комментарий студента</b></font>
#
# Печально, что ты не владеешь данной информацией. Задам данный вопрос наставнику.
#
# Я проводил эксперименты, естественно (обучал модель с различным таргетом - разные обработки, без обработки),  очень детально изучал этот вопрос у специалистов по DS, в их публикациях. Поэтому, я остановился на удалении, в данном случае.
#
# Рассчитывал, что ты подскажешь по данному вопросу.
# </div>

# %% [markdown]
# # Определение возраста покупателей

# %% [markdown]
# Сетевому супермаркету «Хлеб-Соль», который внедряет систему компьютерного зрения для обработки фотографий покупателей, с фотофиксацией в прикассовой зоне, необходимо построить модель машинного обучения (ML - machine learning) для определения приблизительного возраста человека по фотографии.
#
# В нашем распоряжении набор фотографий людей с указанием возраста.
#
# Результат исследования (модель ML) позволит определять возраст клиентов по фотографии, при фотофиксации в прикассовой зоне, и на его основе:
#    - анализировать покупки и предлагать товары, которые могут заинтересовать покупателей этой возрастной группы;
#    - контролировать добросовестность кассиров при продаже алкоголя.
#
# **Цель исследования**
#
#    1. Необходимо построить модель машинного обучения (задача регрессии), с максимальными критериями качества предсказания (c минимальной средней абсолютной ошибкой (MAE)), которая предскажет приблизительный возраст человека.
#    2. Необходимо использовать метрику MAE, для оценки качества модели.
#    3. Значение метрики MAE, для выбранной модели, на тестовой выборке, должно быть не больше 8 (идеальный вариант: менее 7).
#    4. При исследовании, необходимо использовать модель на основе сверточной нейронной сети и библиотеку Keras.
#    5. Обучиние модели необходимо выполнить на GPU.
#
# **Ход исследования**
#
# Данные - набор фотографий людей с указанием возраста, мы получим из директории `/datasets/faces/`, в которой содержится csv-файл `labels.csv` с двумя колонками `file_name` и `real_age` и папка со всеми изображениями `/final_files`.
# О качестве данных ничего не известно. Поэтому, перед анализом данных, понадобится обзор данных.
#
#
# **Исследование пройдёт в пять этапов:**
#   1. Обзор данных;
#   2. Предобработка данных;
#   3. Исследовательский анализ данных;
#   4. Исследование и обучение модели;
#   5. Анализ обученной модели.

# %% [markdown]
# ## Обзор данных
#
# Составим первое представление о данных.

# %% [markdown]
# **1. Установим и импортируем необходимые библиотеки (пакеты).**

# %%
# !pip install --upgrade pandas

# !pip install --upgrade matplotlib

# !pip install --upgrade tensorflow

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Если не секрет - в чем необходимость обновления этих библиотек?  Я запускал код и так и так, насколько я понимаю он работает и без обновления библиотек
#
# Кстати, если установка все-таки нужна, можно использовать флаг -q и устанавливать/обновлять библиотеки с минимумом логов
#
#     !pip install -q nltk
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color: rgb(10, 255, 10);;color:#8737bf">
#     <font size="3"><b>Комментарий студента</b></font>
#
# Команда "!pip install --upgrade <package_name>", обновляет пакет до самого последнего, если он установлен, и устанавливает, если он не установлен.
#
# Необходимость этих команд следующая. Ревьюер, может проверять проект ни только в облаке, в jupyter notebook, но и локально, а библиотеки, которые используются в проверяемом проекте или их необходимые версии, могут быть не установлены на его ПК. Эта же логика экстраполируется на тренажер здесь, в Я.П., (облачный jupyter notebook).
#
# Данные подход, на курсе "специалист DS", прививали нам с самых первых проектов.
# Данный подход делает тетрадку с проектов более переносимой (не привязанной к настроенному окружению среды выполнения).
#
# Помоему, это необходимо в командной работе и не только.
#
# </div>

# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Комментарий ревьюера v2</b>
#
# Тебя понял. Но для восппроизводимости проектов рекомендую тебе фиксировать версии библиотек. Ты обновляешь библиотеки до последней версии,но это легко может поломать код, например изменится поведение функции или название аргументов.
#
#
# </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.resnet_v2 import ResNet152V2
# Out:
# 2023-09-02 14:46:32.566638: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-09-02 14:46:32.569026: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-09-02 14:46:32.617954: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-09-02 14:46:32.618913: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Отлично, все нужные библиотеки импортированы в начале ноутбука.Это хорошая практика.</div>

# %% [markdown]
# **2. Считаем данные из csv-файла в датафрейм и сохраним в переменную df. Путь к файлу:**
# `/datasets/toxic_comments.csv`.

# %%
try:
    # читаем данные из csv-файла и сохраняем их в виде датафрейма в 'df',
    df = pd.read_csv('/datasets/faces/labels.csv')
except:
    print('Warning! Error loading dataframe.')

# %% [markdown]
# **3. Выведем первые пять строчек датафрейма `df` на экран.**

# %%
# посмотрим первых пять строк датафрейма 'df'
df.head()
# Out:
#     file_name  real_age
# 0  000000.jpg         4
# 1  000001.jpg        18
# 2  000002.jpg        80
# 3  000003.jpg        50
# 4  000004.jpg        17

# %% [markdown]
# **4. Выведем основную информацию о датафрейме с помощью метода `info()`.**

# %%
# получение общей информации о данных в датафрейме 'df'
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7591 entries, 0 to 7590
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   file_name  7591 non-null   object
#  1   real_age   7591 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 118.7+ KB

# %% [markdown]
# Итак, в таблице 2 столбца. Типы данных в столбцах: `int64` и `object`.
#
# * `file_name` - имя файла (фотография человека - изображение);
# * `real_age` —  возраст человека (является целевым признаком), изображенного на фото в файле `file_name`.
#
# Количество значений, во всех столбцах, одинаковое, пропуски в данных отсутствуют. Столбцы содержат подходящие типы данных. В названиях колонок (столбцов) таблицы отсутствуют нарушения стиля.

# %% [markdown]
# **5. Построим общую гистограмму для всех числовых столбцов таблицы в датафрейме `df`.**

# %%
# с помощью функции 'hist' построим общую гистограмму
df.hist(figsize=(10, 7), bins= 100);
plt.title('Гистограмма реального возраста людей.', fontsize=15)
plt.xlabel('Возраст (Age)', fontsize=15)
plt.ylabel('Частота (Frequency)', fontsize=15);

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Информативная гистограмма. Молодец, что используешь 100 бинов (корзин).</div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
# Напоминаю, что по правилам оформления проектов у графиков должны быть заголовки и подписаны оси (где это уместно).</div>

# %% [markdown]
# <div class="alert" style="background-color: rgb(10, 255, 10);;color:#8737bf">
#     <font size="3"><b>Комментарий студента</b></font>
#
# Исправлено.
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#     <b>v2</b> 👍 </div>

# %% [markdown]
# **6. Посмотрим статистическую информацию по каждому числовому столбцу таблицы, в датафрейме `df`.**

# %%
# выведем статистическую информацию
df.describe()
# Out:
#           real_age
# count  7591.000000
# mean     31.201159
# std      17.145060
# min       1.000000
# 25%      20.000000
# 50%      29.000000
# 75%      41.000000
# max     100.000000

# %% [markdown]
# **7. Посмотрим 10-ть изображений из датасета.**

# %%
# создадим и инициализируем необходимые константы для будущей подготовки данных и обучения модели
SRC_PATH = '/datasets/faces/'
IMAGES_SUBPATH = 'final_files/'
DATASETS_FILE_NAME = 'labels.csv'
BATCH_SIZE = 16
X_COL = 'file_name'
Y_COL = 'real_age'

IMAGE_HEIGHT = 360
IMAGE_WIDTH = 360
# height, width - images
TARGET_SIZE = (IMAGE_HEIGHT, IMAGE_WIDTH)
CLASS_MODE = 'raw'
RANDOM_SEED = 753



train_datagen =  ImageDataGenerator(validation_split=0.25, rescale=1/255.) # ImageDataGenerator()

train_datagen_flow =\
        train_datagen.flow_from_dataframe(dataframe=df,
                                          directory=SRC_PATH + IMAGES_SUBPATH,
                                          x_col=X_COL,
                                          y_col=Y_COL,
                                          target_size=TARGET_SIZE,
                                          batch_size=BATCH_SIZE,
                                          class_mode=CLASS_MODE,
                                          subset='training',
                                          shuffle=True,
                                          seed=RANDOM_SEED)

features, target = next(train_datagen_flow)

# выводим 10 изображений
fig = plt.figure(figsize=(10,10))
for i in range(10):
    fig.add_subplot(4, 4, i+1)
    plt.imshow(features[i])
	# для компактности удаляем оси и прижимаем изображения друг к другу
    plt.xticks([])
    plt.yticks([])
    plt.tight_layout()
# Out:
# Found 5694 validated image filenames.
# /tmp/ipykernel_114/2421648222.py:42: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %% [markdown]
# На графических изображениях лица людей разных возрастов, которые занимают от 40% до 70% процентов площадь изображения, и содержат многообразный фон.

# %% [markdown]
# <div class="alert" style="background-color: rgb(10, 255, 10);;color:#8737bf">
#     <font size="3"><b>Комментарий студента</b></font>
#
# Добавлено.
#
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#     <b>v2</b> 👍 </div>

# %% [markdown]
# **8. Создадим глобальную переменную для хранения размера исходного датасета.**

# %%
DF_SOURCE_SIZE = df.shape[0]

# %% [markdown]
# **Выводы**
#
# Предварительно можно утверждать, что данных достаточно для исследования. Возможно, есть аномальные значения (артефакты), дубликаты (явные/неявные) и выбросы в данных.
#
# Чтобы двигаться дальше, нужно проверить вышеуказанные проблемы в данных.

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Дальше ты выполняешь необязательный раздел - предобработка данных. Это твое право, свои мысли поповоду работы с выбросами я тебе написал.
#
# Но есть смысл вначале закончить знакомство с данными + написать выводы по этому этапу. И познакомиться с изображениями (не чищенными, не подвергнутыми аугментации) есть смысл именно на этом этапе.
#     .</div>

# %% [markdown]
# <div class="alert" style="background-color: rgb(10, 255, 10);;color:#8737bf">
#     <font size="3"><b>Комментарий студента</b></font>
#
# Выводы указаны.
#
# Что именно ты ожидаешь, напиши конкретику?
# </div>

# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Комментарий ревьюера v2</b>
#
# Я веду речь о структуре проекта. Вначале знакомимся с данными (в том виде, как мы их получили), описываем что есть, и исходя из  этого принимаем решение о дальнейшей предобработке.
#
# Сейчас я вижу что ты добавил исследование исходных изолражений, не подвергнутых аугментации. ОК. Что касается выводов по данному этапу, то вот о чем можно подумать:
#
#    - Размер датасета,а также оценки, достаточно ли фотографий для решения поставленной задачи
#    - Что мы можем сказать о нашем датасете исследовав распределение целевого признака (возраста). Минимальный максимальный возраст, где сконцентрирована большая часть фото, другие особенности, например всплески количества фото в юбилейные годы, что может свидетельствовать о не очень качественной разметки части данных.
#    - Особенности данных, которые мы можем увидеть рассмотрев фото: черно-белые фотографии, посторонние предметы, преобразования, которым были подвергнуты фото (повороты). Да даже то,что на фото есть лица крупным планом уже достойно упоминания.
#    - Рекомендованные аугментации.
#
# </div>

# %% [markdown]
# ## Предобработка данных
#
# Проверим данные на артефакты (аномалии), дубликаты (явные/неявные), выбросы и, при нахождении, исправим.

# %% [markdown]
# ### Обработка дубликатов

# %% [markdown]
# **9. Проверим датафрейм `df` на наличие дубликатов.**

# %%
# проверяем количество строк дубликатов в 'df'
df.duplicated().sum()
# Out:
# 0

# %%
# проверяем количество строк дубликатов в признаке 'file_name', в 'df' 
df['file_name'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# Дубликаты в датафрейме `df` - отсутствуют. Дубликаты в признаке `file_name`, в датафрейме `df` - отсутствуют.

# %% [markdown]
# ### Обработка аномальных значений
#
# В данных могут встречаться артефакты (аномалии) — значения, которые не отражают действительность и появились по какой-то ошибке.
#
# Обработаем аномальные значения, только в тех признаках, которые будут использованы для обучения моделей и предсказаний.

# %% [markdown]
# **10. Проверим аномальные значения в признаке `file_name`.**

# %%
df['file_name'].tolist()
# Out:
# ['000000.jpg',
#  '000001.jpg',
#  '000002.jpg',
#  '000003.jpg',
#  '000004.jpg',
#  '000005.jpg',
#  '000006.jpg',
#  '000007.jpg',
#  '000008.jpg',
#  '000009.jpg',
#  '000010.jpg',
#  '000011.jpg',
#  '000012.jpg',
#  '000013.jpg',
#  '000014.jpg',
#  '000015.jpg',
#  '000016.jpg',
#  '000017.jpg',
#  '000018.jpg',
#  '000019.jpg',
#  '000020.jpg',
#  '000021.jpg',
#  '000022.jpg',
#  '000023.jpg',
#  '000024.jpg',
#  '000025.jpg',
#  '000026.jpg',
#  '000027.jpg',
#  '000028.jpg',
#  '000029.jpg',
#  '000030.jpg',
#  '000031.jpg',
#  '000032.jpg',
#  '000033.jpg',
#  '000034.jpg',
#  '000035.jpg',
#  '000036.jpg',
#  '000037.jpg',
#  '000038.jpg',
#  '000039.jpg',
#  '000040.jpg',
#  '000041.jpg',
#  '000042.jpg',
#  '000043.jpg',
#  '000044.jpg',
#  '000045.jpg',
#  '000046.jpg',
#  '000047.jpg',
#  '000048.jpg',
#  '000049.jpg',
#  '000050.jpg',
#  '000051.jpg',
#  '000052.jpg',
#  '000053.jpg',
#  '000054.jpg',
#  '000055.jpg',
#  '000056.jpg',
#  '000057.jpg',
# ...

# %% [markdown]
# Аномальные значения отсутствуют.

# %% [markdown]
# **11. Проверим аномальные значения в признаке `real_age`.**

# %%
# посмотрим, сколько людей в датасете в возрасте менее пяти лет
df[df['real_age'] < 5]['real_age'].count()
# Out:
# 363

# %% [markdown]
# Людей в возрасте менее пяти лет - 363 человека. Данные люди не могут самостоятельно ходить в магазин, по объективным причинам. Следовательно, эти данные аномальные и их необходимо удалить из целевого признака.

# %%
# удалим аномальные значения
df = df[df['real_age'] >= 5]

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# На мой взгляд ты зря удаляешь детские фото из датасета. Во первых, в тестовых данных все-таки будут изображения с детьми и модель не научится с ними работать. А если в процессе эксплуатации модели она получит изображение ребенка, то не будет понимать, как с ним работать.
#
# Оставляю комментарий желтым, т.к. на тестирование модели данный шаг не влияет.
# </div>

# %% [markdown]
# <div class="alert" style="background-color: rgb(10, 255, 10);;color:#8737bf">
#     <font size="3"><b>Комментарий студента</b></font>
#
# Почему не будет понимать? Все очень просто. Все реальные модели CV, которые работают в проде, то, что они не могут определить (классифицировать/ распознать), отбрасывают и все.
#
# Контекст задачи у нас такой: "Результат исследования (модель ML) позволит определять возраст клиентов по фотографии, при фотофиксации в прикассовой зоне, и на его основе:
#  - анализировать покупки и предлагать товары, которые могут заинтересовать покупателей этой возрастной группы;
#  - контролировать добросовестность кассиров при продаже алкоголя.
# "
#
# То есть, система CV, в контексте нашей задачи, ориентирована на дееспособных покупателей, которые могут выбирать и покупать товар самостоятельно. Остальные не интересны. Дети до пяти лет, за исключением единиц, не могут сами покупать товар в магазине. Следовательно, люди младши пяти лет, внедряемой системе CV, и следовательно нашей модели, не интересны.
#
#
# Вот такой логикой я руководствовался.
# </div>

# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Комментарий ревьюера v2</b>
#
# ОК, не вижу смысла в дискуссии</div>

# %%
# посмотрим, сколько людей в датасете в возрасте более 100 лет
df[df['real_age'] > 100]['real_age'].count()
# Out:
# 0

# %% [markdown]
# Аномальные значения отсутствуют.

# %% [markdown]
# ### Обработка выбросов

# %% [markdown]
# **12. Проверим датасет: `df`, на наличие выбросов.**

# %%
# построим диаграмму размаха для датафрейма 'df', чтобы проверить признаки на наличие выбросов
df.plot(kind='box',
        vert=False,
        title='Значения численных признаков датасета \'df\'',
        grid=True);

# %% [markdown]
# Целевой признак `real_age` имеет выбросы, которые могут повлиять на результат нашего исследования (повлияет на точность модели ML) и привести к переобучению модели.

# %%
# построим гистограмму и график распределения значений признака
fig, ax = plt.subplots(figsize=(10, 7))
df['real_age'].plot.kde(ax=ax,
                        legend=False,
                        linewidth=3,
                        color='red')

df['real_age'].plot.hist(density=True,
                         color='blue',
                         rwidth=0.9,
                         alpha=0.75,
                         ax=ax)

plt.title('Histogram and graph real age.', fontsize=15)
plt.xlabel('Age', fontsize=15)
plt.ylabel('Frequency', fontsize=15)
ax.grid(alpha=0.5)
ax.set_facecolor('#d8dcd6')

# %% [markdown]
# Из гистограммы и графика распределения видно, что это правостороннее распределение, с положительной асимметрией. Данное распределение является асимметрично-нормальным распределением (распределение графика имеет только один пик, значение перекоса не равно нулю).
#
# Наличие асимметрии в данных приведет к потере точности работы модели ML и к ее переобучению. Следовательно, для улучшения модели, их необходимо скорректировать на этапе подготовки данных.
#
# Для корректировки данных удалим выбросы, так как их процент от объема всей выборки не более **10%**.

# %% [markdown]
# **13. Удалим выбросы в целевом признаке `real_age`.** <a id='step_12'></a>

# %%
/# функция вычисления левой и правой границы (левое и правое "крайние" значения данных) [на диаграмме размаха]
# параметр 'feature' - признак (столбец из датафрейма)
def left_right_extreme_data_boundary(feature):
    
    if(feature.empty):
        return np.nan, np.nan
    
    # вычислим квантили q3 (75%-й) и q1 (25% -й)
    q3, q1 = np.percentile(feature, [75,25])
    
    # вычислим межквантильный интервал iqr
    iqr = q3 - q1

    # рассчитаем левую и правую границу (левое и правое "крайние" значения данных)
    return np.around((q1 - iqr * 1.5), decimals=3), np.around((q3 + iqr * 1.5), decimals=3)



# функция обработки выбросов в одном признаке
def outlier_handling_in_feature(dataframe,
                                column_name,
                                min_range_limit,
                                max_range_limit):
    
    # удалим из датасета выбросы 'dataframe', из столбца 'column_name', выбросы
    dataframe = dataframe[~(dataframe[column_name] < min_range_limit) &
                          ~(dataframe[column_name] > max_range_limit)]
    
    return dataframe



def check_in_outlier(features, column_names):
    
    for column_name in column_names:
        left_border, right_border = left_right_extreme_data_boundary(features[column_name].fillna(0))
        
        if ( (left_border > features[column_name].min()) or
             (right_border < features[column_name].max()) ):
            return False
        
    return True


# функция обработки выбросов в одном датафрейме
def outlier_handling(features, column_names):
    
    work = True;
    while(work):
        for column_name in column_names:
        
            left_border, right_border = left_right_extreme_data_boundary(features[column_name].fillna(0))
        
        
            features = outlier_handling_in_feature(features,
                                                   column_name,
                                                   left_border,
                                                   right_border)
        
        if (features.empty or check_in_outlier(features, column_names)):
            break
    
    return features

# %%
# построим гистограмму целевого признака 
df['real_age'].plot(kind='hist',
                    grid=True,
                    xlabel='Age',
                    ylabel='Frequency',
                    title='Real age',
                    figsize=(10, 7),
                    bins=30);

# %%
# удалим выбросы в целевом признаке датафрейма 'df'
df = outlier_handling(df, ['real_age'])

# %%
# построим гистограмму целевого признака, после преобразования
df['real_age'].plot(kind='hist',
                    grid=True,
                    xlabel='Age',
                    ylabel='Frequency',
                    title='Real age after transformation.',
                    figsize=(10, 7),
                    bins=30);

# %%
# построим диаграмму размаха целевого признака, датафрейма 'df', после преобразования
df['real_age'].plot(kind='box',
                    vert=False,
                    xlabel='Age',
                    title='Real age',
                    grid=True);

# %% [markdown]
# После удаления выбросов в целевом признаке, распределение стало более симметричным и ближе к нормальному (распределением Гаусса).

# %% [markdown]
# **14. Проверим, какая доля исходного датасета осталась после фильтрации.**

# %%
# рассчитаем размер доли исходного датасета 'df', которая осталась после фильтрации, в процентах
(df.shape[0] / DF_SOURCE_SIZE) * 100
# Out:
# 91.79291265972861

# %% [markdown]
# Размер доли исходного датасета, которая осталась после фильтрации:
#
# * `df` - **`91.79291265972861`**.

# %% [markdown]
# **Выводы**
#
# 1. Предобработка обнаружила следующие проблемы в данных:
#
# - выбросы в целевом признаке;
# - аномальные значения.
#
#
# 2. Удалили выбросы в целевом признаке.
# 3. Удалили аномальные значения.
#
# После такой предобработки данных, исследование станет более точным.
#
# Теперь можно перейти к исследовательскому анализу данных.

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#  👍 Да, вижу ты отработал функции по чистке, которые применил в дальнейшем при обучении модели </div>

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# **15. Посмотрим размер выборки.**

# %%
df.shape
# Out:
# (6968, 2)

# %% [markdown]
# **16. Построим гистограмму и график распределения значений признака `real_age`.**

# %%
fig, ax = plt.subplots(figsize=(10, 7))
df['real_age'].plot.kde(ax=ax,
                        legend=False,
                        linewidth=3,
                        color='red')

df['real_age'].plot.hist(density=True,
                         color='blue',
                         rwidth=0.9,
                         alpha=0.75,
                         ax=ax)

plt.title('Histogram and graph real age.', fontsize=15)
plt.xlabel('Age', fontsize=15)
plt.ylabel('Frequency', fontsize=15)
ax.grid(alpha=0.5)
ax.set_facecolor('#d8dcd6')

# %% [markdown]
# **17. Посмотрим статистическую информацию целевого признака `real_age`, в датафрейме `df`.**

# %%
# выведем статистическую информацию признака 'real_age'
df['real_age'].describe()
# Out:
# count    6968.000000
# mean       30.963548
# std        13.864436
# min         5.000000
# 25%        21.000000
# 50%        29.000000
# 75%        40.000000
# max        68.000000
# Name: real_age, dtype: float64

# %% [markdown]
# **18. Выведем 15-ть изображений из датасета.**

# %%
# переопределим переменные (объекты классов) 'train_datagen' и 'train_datagen_flow'
train_datagen = ImageDataGenerator(width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   horizontal_flip=True,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   rescale=1/255.,
                                   validation_split=0.25)

valid_datagen = ImageDataGenerator(validation_split=0.25, rescale=1/255.)



train_datagen_flow =\
        train_datagen.flow_from_dataframe(dataframe=df,
                                          directory=SRC_PATH + IMAGES_SUBPATH,
                                          x_col=X_COL,
                                          y_col=Y_COL,
                                          target_size=TARGET_SIZE,
                                          batch_size=BATCH_SIZE,
                                          class_mode=CLASS_MODE,
                                          subset='training',
                                          shuffle=True,
                                          seed=RANDOM_SEED)


valid_datagen_flow =\
        valid_datagen.flow_from_dataframe(dataframe=df,
                                          directory=SRC_PATH + IMAGES_SUBPATH,
                                          x_col=X_COL,
                                          y_col=Y_COL,
                                          target_size=TARGET_SIZE,
                                          batch_size=BATCH_SIZE,
                                          class_mode=CLASS_MODE,
                                          subset='validation',
                                          shuffle=True,
                                          seed=RANDOM_SEED)


features, target = next(train_datagen_flow)

# выводим 15 изображений
fig = plt.figure(figsize=(10,10))
for i in range(15):
    fig.add_subplot(4, 4, i+1)
    plt.imshow(features[i])
	# для компактности удаляем оси и прижимаем изображения друг к другу
    plt.xticks([])
    plt.yticks([])
    plt.tight_layout()
# Out:
# Found 5226 validated image filenames.
# Found 1742 validated image filenames.
# /tmp/ipykernel_114/2996784765.py:50: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Очень хорошо, что выведены фотографии. Это хорошая практика, помогает увидеть изображения, с которыми будет работать наша модель, заметить какие-то детали и особенности, улучшить понимание задачи и получить определенную интуицию. А также заранее оценить подходящие для наших данных методы аугментации. </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Но изначально все-таки советую посмотреть неаугментированные изображения. Хотя посмореть аугментированные тоже полезно, мы понимаем, как учится модель.</div>

# %% [markdown]
# <div class="alert" style="background-color: rgb(10, 255, 10);;color:#8737bf">
#     <font size="3"><b>Комментарий студента</b></font>
#
# Посмотрел. Посмотри восьмой шаг, на  первом этапе исследования (обзор данных).
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#     <b>v2</b> 👍 </div>

# %% [markdown]
# **Выводы**
#
#   1. Размер датафрейма, небольшой - 7591 записей.
#
#
#
#   2. Имеет всего два признака, один из которых целевой (`real_age`), а второй, имена файлов - графических изображений.
#
#
#
#   3. Целевой признак имел выбросы, которые могли повлиять на результат нашего исследования (повлияет на точность модели ML) и привести к переобучению модели, и были удалены на шаге [преобразования целевого признака](#step_12).
#
#
#   4. Из гистограммы и графика распределения видно, что оно стало, после [шага 12](#step_12), почти симметричным и нормальным (распределением Гаусса).
#
#
#   5. На графических изображениях лица людей разных возрастов, которые занимают от 40% до 70% процентов площадь изображения, и содержат многообразный фон. Такой набор признаков (изображения) для обучения, позволит хорошо обучить модель ML для реальных условий работы.

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Очень хорошо, выполнен EDA и сформулированы выводы. В выводах рассмотрены три ключевых аспекта:
#
#  - Размер датасета
#  - Распределение целевого признака (возраста)
#  - Особенности изображений, входящих в датасет
# </div>

# %% [markdown]
# ## Исследование и обучение модели

# %% [markdown]
# В качестве модели машинного обучения - ML на основе сверточной нейронной сети, была выбрана модель `ResNet152V2` из библиотеки `Keras`.
#
#
#
#
# Исходный код обучения модели на GPU в тренажере.

# %% [markdown]
# ```python
#
# # исходный код обучения модели на GPU (в тренажёре)
# import pandas as pd
# import numpy as np
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
# from tensorflow.keras.optimizers import Adam
# from tensorflow.keras.applications.resnet_v2 import ResNet152V2
#
#
# SRC_PATH = '/datasets/faces/'
# IMAGES_SUBPATH = 'final_files/'
# DATASETS_FILE_NAME = 'labels.csv'
# BATCH_SIZE = 16
# X_COL = 'file_name'
# Y_COL = 'real_age'
#
# IMAGE_HEIGHT = 360
# IMAGE_WIDTH = 360
# # height, width - images
# TARGET_SIZE = (IMAGE_HEIGHT, IMAGE_WIDTH)
# CLASS_MODE = 'raw'
# RANDOM_SEED = 753
#
#
# # функция вычисления левой и правой границы (левое и правое "крайние" значения данных) [на диаграмме размаха]
# # параметр 'feature' - признак (столбец из датафрейма)
# def left_right_extreme_data_boundary(feature):
#
#     if(feature.empty):
#         return np.nan, np.nan
#
#     # вычислим квантили q3 (75%-й) и q1 (25% -й)
#     q3, q1 = np.percentile(feature, [75,25])
#
#     # вычислим межквантильный интервал iqr
#     iqr = q3 - q1
#
#     # рассчитаем левую и правую границу (левое и правое "крайние" значения данных)
#     return np.around((q1 - iqr * 1.5), decimals=3), np.around((q3 + iqr * 1.5), decimals=3)
#
#
#
# # функция обработки выбросов в одном признаке
# def outlier_handling_in_feature(dataframe,
#                                 column_name,
#                                 min_range_limit,
#                                 max_range_limit):
#
#     # удалим из датасета выбросы 'dataframe', из столбца 'column_name', выбросы
#     dataframe = dataframe[~(dataframe[column_name] < min_range_limit) &
#                           ~(dataframe[column_name] > max_range_limit)]
#
#     return dataframe
#
#
#
# def check_in_outlier(features, column_names):
#
#     for column_name in column_names:
#         left_border, right_border = left_right_extreme_data_boundary(features[column_name].fillna(0))
#
#         if ( (left_border > features[column_name].min()) or
#              (right_border < features[column_name].max()) ):
#             return False
#
#     return True
#
#
# # функция обработки выбросов в одном датафрейме
# def outlier_handling(features, column_names):
#
#     work = True;
#     while(work):
#         for column_name in column_names:
#
#             left_border, right_border = left_right_extreme_data_boundary(features[column_name].fillna(0))
#
#
#             features = outlier_handling_in_feature(features,
#                                                    column_name,
#                                                    left_border,
#                                                    right_border)
#
#         if (features.empty or check_in_outlier(features, column_names)):
#             break
#
#     return features
#
# def load_train(path=SRC_PATH):
#
#     train_datagen = ImageDataGenerator(width_shift_range=0.2,
#                                        height_shift_range=0.2,
#                                        horizontal_flip=True,
#                                        shear_range=0.2,
#                                        zoom_range=0.2,
#                                        rescale=1/255.,
#                                        validation_split=0.25)
#
#     df = pd.read_csv(path + DATASETS_FILE_NAME)
#     df = df[df['real_age'] >= 5]
#     df = outlier_handling(df, ['real_age'])
#
#     train_datagen_flow =\
#         train_datagen.flow_from_dataframe(dataframe=df,
#                                           directory=path + IMAGES_SUBPATH,
#                                           x_col=X_COL,
#                                           y_col=Y_COL,
#                                           target_size=TARGET_SIZE,
#                                           batch_size=BATCH_SIZE,
#                                           class_mode=CLASS_MODE,
#                                           subset='training',
#                                           shuffle=True,
#                                           seed=RANDOM_SEED)
#
#     return train_datagen_flow
#
#
# def load_test(path=SRC_PATH):
#
#     valid_datagen = ImageDataGenerator(validation_split=0.25, rescale=1/255.)
#
#     valid_datagen_flow =\
#         valid_datagen.flow_from_dataframe(dataframe=pd.read_csv(path + DATASETS_FILE_NAME),
#                                           directory=path + IMAGES_SUBPATH,
#                                           x_col=X_COL,
#                                           y_col=Y_COL,
#                                           target_size=TARGET_SIZE,
#                                           batch_size=BATCH_SIZE,
#                                           class_mode=CLASS_MODE,
#                                           subset='validation',
#                                           shuffle=True,
#                                           seed=RANDOM_SEED)
#
#     return valid_datagen_flow
#
#
# def create_model(input_shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3),
#                  weights='imagenet',
#                  activation_functions='elu', learning_rate=0.00005,
#                  loss='mse', metrics=['mae']):
#
#     optimizer = Adam(learning_rate=learning_rate)
#
#     backbone = ResNet152V2(include_top=False,
#                            weights=weights,
#                            input_shape=input_shape)
#
#     model = Sequential()
#     model.add(backbone)
#     model.add(GlobalAveragePooling2D())
#     model.add(Dense(units=1, activation=activation_functions))
#     model.compile(optimizer=optimizer, loss=loss, metrics=metrics)
#
#     return model
#
#
#
# def train_model(model, train_data, test_data, batch_size=None, epochs=15,
#                 steps_per_epoch=None, validation_steps=None):
#     try:
#         model.fit(train_data,
#                   validation_data=test_data,
#                   batch_size=batch_size,
#                   epochs=epochs,
#                   steps_per_epoch=steps_per_epoch,
#                   validation_steps=validation_steps,
#                   verbose=2,
#                   shuffle=True)
#
#         model.save_weights('ResNet152V2_weights_real_age.h5')
#
#         model = create_model(input_shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3),
#                              weights=None,
#                              activation_functions='relu', learning_rate=0.00001)
#
#         model.load_weights('ResNet152V2_weights_real_age.h5')
#
#         model.fit(train_data,
#                   validation_data=test_data,
#                   batch_size=batch_size,
#                   epochs=15,
#                   steps_per_epoch=steps_per_epoch,
#                   validation_steps=validation_steps,
#                   verbose=2,
#                   shuffle=True)
#
#     except Exception as exception:
#         print('Exception', exception)
#
#     return model
#
# ```

# %% [markdown]
# Вывод результата обучения модели.

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Написаны функции для создания датагенераторов, а также создания и обучения модели.
# <hr>
# Молодец, что используешь агументацию для обучающего набора.
# <hr>
#
# Правильный выбор лосс-функции, также хорошо подобран шаг обучения.</div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Модель ResNEt обучалась на изображениях размером 224х224. Подавая изображения других размеров ты используешь модель не в оптимальном режиме.
# </div>

# %% [markdown]
# <div class="alert" style="background-color: rgb(10, 255, 10);;color:#8737bf">
#     <font size="3"><b>Комментарий студента</b></font>
#
# Я использовал разрешение 224x224, для входных изображений, при обучении модели (input_shape), но на тех же гиперпараметрах, результат модели был хуже (MAE была больше).
#
#
# В документации указано: "optional shape tuple, only to be specified if include_top is False (otherwise the input shape has to be (224, 224, 3) (with 'channels_last' data format) or (3, 224, 224) (with 'channels_first' data format). It should have exactly 3 inputs channels, and width and height should be no smaller than 32. E.g. (200, 200, 3) would be one valid value."
#
# "It should have exactly 3 inputs channels, and width and height should be no smaller than 32. E.g. (200, 200, 3) would be one valid value. " - "Он должен иметь ровно 3 входных канала, а ширина и высота должны быть не меньше 32. (200, 200, 3) будет одним допустимым значением." Таким обрзом, разрешение 256x256, считается валидным. И опыт использования разрешения изображений более 224x224, показан не в одной работе и статье.
#
# Хотел бы услышать твое мнение на этот счет с примерами на источники.
#
# Изменил, для закрытия данного пункта.
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#     <b>v2</b> Да, я понимаю, что благодаря пулингам модель может принимать изображения любых размеров. Цель моего комментария - обратить твое внимание на родной размер изображения.  Другие модели могут оказаться не такими гибкими и при подаче избражений других размеров просто "сломаются".
#
#
# Если ты пошел на выбор размера изображения осознанно, руководствуясь статьями - твое право. В нейронных сетях вообще многие вещи определяются экспериментально.
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Молодец, что использовал новую модель, но каков выигрыш Resnet152 по сравнению с Resnet50 и окупится ли он увеличением времени обучения?</div>

# %% [markdown]
# <div class="alert" style="background-color: rgb(10, 255, 10);;color:#8737bf">
#     <font size="3"><b>Комментарий студента</b></font>
#
# Я использую архитектуру `ResNet_X_V2`, а не `ResNet_X` (где X = [50, 101, 152]). Вариант 152.
# Отличие ResNet_X_V2 (ResNet152V2) от ResNet_X (ResNet152) хорошо показано тут: https://www.kaggle.com/code/ifurkanbozkurt/6-resnet-models-and-mask-detection (в конце есть графики).
#
# Отличие  `ResNet152V2` от `ResNet50V2` - более точное решение (ошибка (MAE) меньше), а время обучения незначительно больше.
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#     <b>v2</b> ОК, если выбор модели ты провел осознанно </div>

# %% [markdown]
# ```
#
# #
# Train for 327 steps, validate for 119 steps
#
# Epoch 1/15
#
# 327/327 - 236s - loss: 296.4239 - mae: 13.6209 - val_loss: 127.6506 - val_mae: 8.5955
#
# Epoch 2/15
#
# 327/327 - 174s - loss: 98.1814 - mae: 7.6383 - val_loss: 139.8251 - val_mae: 8.8049
#
# Epoch 3/15
#
# 327/327 - 173s - loss: 65.2744 - mae: 6.2603 - val_loss: 99.7008 - val_mae: 7.5861
#
# Epoch 4/15
#
# 327/327 - 173s - loss: 53.0953 - mae: 5.7037 - val_loss: 102.8961 - val_mae: 7.5112
#
# Epoch 5/15
#
# 327/327 - 228s - loss: 44.7796 - mae: 5.2131 - val_loss: 75.4588 - val_mae: 6.5029
#
# Epoch 6/15
#
# 327/327 - 232s - loss: 39.4225 - mae: 4.8804 - val_loss: 69.6267 - val_mae: 5.9419
#
# Epoch 7/15
#
# 327/327 - 219s - loss: 36.7122 - mae: 4.6481 - val_loss: 80.5353 - val_mae: 6.4141
#
# Epoch 8/15
#
# 327/327 - 170s - loss: 31.6940 - mae: 4.4320 - val_loss: 78.0862 - val_mae: 6.2145
#
# Epoch 9/15
#
# 327/327 - 203s - loss: 28.1777 - mae: 4.1666 - val_loss: 66.1072 - val_mae: 5.9387
#
# Epoch 10/15
#
# 327/327 - 234s - loss: 28.4663 - mae: 4.1618 - val_loss: 64.0473 - val_mae: 5.8286
#
# Epoch 11/15
#
# 327/327 - 213s - loss: 26.1511 - mae: 4.0039 - val_loss: 83.3331 - val_mae: 6.5852
#
# Epoch 12/15
#
# 327/327 - 173s - loss: 25.0242 - mae: 3.8862 - val_loss: 79.2525 - val_mae: 6.4367
#
# Epoch 13/15
#
# 327/327 - 172s - loss: 23.3906 - mae: 3.7939 - val_loss: 74.7719 - val_mae: 6.2340
#
# Epoch 14/15
#
# 327/327 - 172s - loss: 22.6065 - mae: 3.7213 - val_loss: 77.9487 - val_mae: 6.2836
#
# Epoch 15/15
#
# 327/327 - 173s - loss: 20.8161 - mae: 3.5687 - val_loss: 66.9265 - val_mae: 5.9692
#
#
# WARNING:tensorflow:sample_weight modes were coerced from
#
#   ...
#
#     to
#
#   ['...']
#
# WARNING:tensorflow:sample_weight modes were coerced from
#
#   ...
#
#     to
#
#   ['...']
#
# Train for 327 steps, validate for 119 steps
#
# Epoch 1/15
#
# 327/327 - 189s - loss: 15.7819 - mae: 3.0477 - val_loss: 56.9881 - val_mae: 5.5945
#
# Epoch 2/15
#
# 327/327 - 169s - loss: 12.0547 - mae: 2.7012 - val_loss: 61.3542 - val_mae: 5.6307
#
# Epoch 3/15
#
# 327/327 - 171s - loss: 10.1390 - mae: 2.5088 - val_loss: 58.5245 - val_mae: 5.5762
#
# Epoch 4/15
#
# 327/327 - 172s - loss: 8.7115 - mae: 2.3221 - val_loss: 57.2370 - val_mae: 5.5415
#
# Epoch 5/15
#
# 327/327 - 173s - loss: 7.8027 - mae: 2.1692 - val_loss: 59.5540 - val_mae: 5.5704
#
# Epoch 6/15
#
# 327/327 - 180s - loss: 7.2632 - mae: 2.0913 - val_loss: 58.5381 - val_mae: 5.6968
#
# Epoch 7/15
#
# 327/327 - 174s - loss: 6.3748 - mae: 1.9671 - val_loss: 57.5611 - val_mae: 5.5144
#
# Epoch 8/15
#
# 327/327 - 179s - loss: 6.2714 - mae: 1.9208 - val_loss: 57.5378 - val_mae: 5.5256
#
# Epoch 9/15
#
# 327/327 - 173s - loss: 5.5189 - mae: 1.8262 - val_loss: 56.5279 - val_mae: 5.4844
#
# Epoch 10/15
#
# 327/327 - 174s - loss: 5.0473 - mae: 1.7556 - val_loss: 57.2653 - val_mae: 5.4924
#
# Epoch 11/15
#
# 327/327 - 173s - loss: 5.0248 - mae: 1.7335 - val_loss: 58.4313 - val_mae: 5.4628
#
# Epoch 12/15
#
# 327/327 - 175s - loss: 4.9542 - mae: 1.7224 - val_loss: 60.6482 - val_mae: 5.5976
#
# Epoch 13/15
#
# 327/327 - 173s - loss: 4.5332 - mae: 1.6674 - val_loss: 57.3426 - val_mae: 5.5447
#
# Epoch 14/15
#
# 327/327 - 174s - loss: 4.3414 - mae: 1.6140 - val_loss: 58.4409 - val_mae: 5.5311
#
# Epoch 15/15
#
# 327/327 - 174s - loss: 4.2156 - mae: 1.5838 - val_loss: 57.2851 - val_mae: 5.4972
#
# WARNING:tensorflow:sample_weight modes were coerced from
#
#   ...
#
#     to
#
#   ['...']
#
# 119/119 - 13s - loss: 57.2851 - mae: 5.4972
#
# Test MAE: 5.4972
#
# ```

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Модель обучена и преодолела планку требуемой точности </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Как я писал выше, лучше всего проверять теории экспериментально. В этом проекте порог, о котором пишут авторы датасета составляет 5,4.  И по моему опыту он достаточно легко "выбивается" без работы с выбросами. Легкая аугменатация, эпох 30 на lr=0.0001 и дообучаем на lr=0.00001.
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color: rgb(10, 255, 10);;color:#8737bf">
#     <font size="3"><b>Комментарий студента</b></font>
#
# Спасибо за информацию.
#
# Как вариант. Мы же обучаем нашу модель, на предобученных весах, а не с нуля.
# Кто мешает это сделать еще несколько раз, с разными гиперпараметрами. Я видел такую технику ни в одной статье.
#
# Количество таких обучений на предобученной модели, может быть n - [1, бесконечность]. Рекурсия в обучении модели.
#
# </div>

# %% [markdown]
# ## Анализ обученной модели

# %% [markdown]
# **Выводы**
#
# Выбранная модель сверточной нейронной сети - `ResNet152V2`, является одной из лучших архитектур сверточных нейронных сетей, по скорости обучения и качеству работы, в задачах распознавания графических образов.
#
# Плюсом выбранной модели, из библиотеки `Keras`, является наличие возможности использовать предобученные веса данной нейронной сети, которые уже обучены на большом массиве данных(изображений), распознавать различные графические образы. Таким образом, нам не нужно обучать данную модель нейронной сети с нуля, а достаточно дообучить под нашу задачу. Это существенно ускоряет процесс обучения и получения готовой модели с максимальными критериями качества и с минимальными ошибками.
#
#
# Модель `ResNet152V2`, `MAE` на тестовой выборке: **5.4972**.
#
# Количество эпох (`epochs`), которое потребовалось для обучения: **15 + 15 = 30**.
#
# Модель `ResNet152V2`:
#  - Гиперпараметры модели `ResNet152V2`:
#
#    Первая итерация дообучения:
#    * `input_shape`          - **(None, 256, 256, 3)**;
#    * `weights`              - **imagenet**;
#    * `activation_functions` - **elu**;
#    * `learning_rate`        - **0.00005**;
#
#    Вторая итерация дообучения:
#    * `input_shape`          - **(None, 256, 256, 3)**;
#    * `weights`              - **imagenet**;
#    * `activation_functions` - **relu**;
#    * `learning_rate`        - **0.00001**;
#
#
#  - Функция потерь:   `loss`    - '**mse**;
#  - Метрика качества: `metrics` - **mae**.
#
#
#
# *Рекомендации по улучшению модели*:
#    - собрать большой массив исходных данных для обучения модели (по ссылке https://chalearnlap.cvc.uab.es/dataset/26/description/ намного больше данных, чем датасет, который используется в тренажёре и взят из датасета по ссылке.);
#    - обучить модель на большом массиве данных;
#    - провести исследование модели на большем множестве параметров модели;
#    - скорректировать параметры модели (hyperparameter tuning);
#    - обучить модель на большом количестве эпох (от 500 и более) и с большей точностью (коэффициент скорости обучения) (параметр : `learning_rate`).

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Указаны основные моменты, касающиеся построения сети и её обучения.
#
# Что касается датасета по ссылке - мы использовали его весь. `The APPA-REAL database contains 7,591 images with associated real and apparent age labels`. Вся разница только в том, что в оригинальном датасете зафиксировано разбиение на обучение/валидацию/тест, а у нас разбиение произошло по другому.
#
#
# </div>

# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Заключительный комментарий</b>
#
# Давай подведем итоги.
# Ты провел содержательный EDA, а также использовал предобученную модель и c помощью finetuning и transfer-learning обучил нейронку определять возраст покупателей. Требуемая точность получена.
#
# Очень интересное исследование с удалением выбросов из обучающих данных.
#
#
# Пожалуста проверь,чтобы у всех графиков было название и подписаны оси.
#
#
#
#
# Жду твой проект на финальное ревью :)
# </div>

# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> дополнительные материалы </b>
# В курсе уже есть ссылки на отдельные статьи. Со своей стороны поделюсь неплохими бесплатными курсами по нейронкам, дающим целостную картинку.
#
#    - "Дип Лернинг на пальцах" (https://www.youtube.com/playlist?list=PL5FkQ0AF9O_o2Eb5Qn8pwCDg7TniyV1Wb).
#    - Отличный бесплатный курс от Школы глубокого обучения МФТИ (https://stepik.org/org/dlschool), старт курса каждые пол года. Два семестра, один по основам и компьютерному зрению, второй по обработке естественного языка.
#    - "Нейронные сети и компьютерное зрение" от Samsung Research Russia (https://stepik.org/course/50352/syllabus). Есть также продолжение по NLP.
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color: rgb(10, 255, 10);;color:#8737bf">
#     <font size="3"><b>Комментарий студента</b></font>
#
# Спасибо за  полезную информацию.
#
# </div>

# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Заключительный комментарий v2</b>
#
# Проект принят. Поздравляю и желаю дальнейших успехов!
# </div>
